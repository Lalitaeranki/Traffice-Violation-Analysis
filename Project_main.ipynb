# %%
#Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
#Read the cvs file

Traffic_pd=pd.read_csv("Traffic_Violations.csv")

# %%
Traffic_pd.head()
# Out:
#   Date Of Stop Time Of Stop Agency  \
# 0   09/24/2013     17:11:00    MCP
# 1   08/29/2017     10:19:00    MCP
# 2   12/01/2014     12:52:00    MCP
# 3   08/29/2017     09:22:00    MCP
# 4   08/28/2017     23:41:00    MCP
#
#                                          SubAgency  \
# 0                      3rd district, Silver Spring
# 1                           2nd district, Bethesda
# 2  6th district, Gaithersburg / Montgomery Village
# 3                      3rd district, Silver Spring
# 4  6th district, Gaithersburg / Montgomery Village
#
#                                          Description  \
# 0  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 1  DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 2                 FAILURE STOP AND YIELD AT THRU HWY
# 3               FAILURE YIELD RIGHT OF WAY ON U TURN
# 4  FAILURE OF DR. TO MAKE LANE CHANGE TO AVAIL. L...
#
#                                  Location   Latitude  Longitude Accident  \
# ...

# %%
Traffic_pd.columns
# Out:
# Index(['Date Of Stop', 'Time Of Stop', 'Agency', 'SubAgency', 'Description',
#        'Location', 'Latitude', 'Longitude', 'Accident', 'Belts',
#        'Personal Injury', 'Property Damage', 'Fatal', 'Commercial License',
#        'HAZMAT', 'Commercial Vehicle', 'Alcohol', 'Work Zone', 'State',
#        'VehicleType', 'Year', 'Make', 'Model', 'Color', 'Violation Type',
#        'Charge', 'Article', 'Contributed To Accident', 'Race', 'Gender',
#        'Driver City', 'Driver State', 'DL State', 'Arrest Type',
#        'Geolocation'],
#       dtype='object')

# %%
Traffic_pd=Traffic_pd.rename(columns={'Year':'Year Make'})
Traffic_pd.columns
# Out:
# Index(['Date Of Stop', 'Time Of Stop', 'Agency', 'SubAgency', 'Description',
#        'Location', 'Latitude', 'Longitude', 'Accident', 'Belts',
#        'Personal Injury', 'Property Damage', 'Fatal', 'Commercial License',
#        'HAZMAT', 'Commercial Vehicle', 'Alcohol', 'Work Zone', 'State',
#        'VehicleType', 'Year Make', 'Make', 'Model', 'Color', 'Violation Type',
#        'Charge', 'Article', 'Contributed To Accident', 'Race', 'Gender',
#        'Driver City', 'Driver State', 'DL State', 'Arrest Type',
#        'Geolocation'],
#       dtype='object')

# %%
#getting Year and month  using datetype


Traffic_pd['Date Of Stop'] = pd.to_datetime(Traffic_pd['Date Of Stop'])
#Traffic_pd['Date Of Stop'].dt.year
Traffic_pd['Year'] = Traffic_pd['Date Of Stop'].dt.year
Traffic_pd['Month'] =Traffic_pd['Date Of Stop'].dt.month

# %%
Traffic_pd.shape
# Out:
# (1373693, 37)

# %%
Traffic_Data=Traffic_pd.loc[:,['Description', 'Violation Type','Charge','Fatal', 'Race', 'Gender','Year','Month']]

# %%
Traffic_Data.Charge.value_counts()
# Out:
# 21-801.1          174730
# 21-201(a1)        110621
# 13-409(b)          65405
# 13-401(h)          46152
# 21-707(a)          44205
# 16-112(c)          36112
# 21-1124.2(d2)      33796
# 13-411(f)          32867
# 16-101(a)          31155
# 16-303(h)          28763
# 16-303(c)          28512
# 64*                26756
# 22-412.3(b)        26631
# 21-801(a)          23955
# 13-411(d)          22603
# 21-309(b)          19598
# 22-201.1           19234
# 21-901.1(b)        18267
# 13-411(a)          17445
# 21-202(h1)         16433
# 16-116(a)          16256
# 21-801(b)          16004
# 21-902(b1)         15359
# 21-902(a1)         15104
# 22-204(f)          14680
# 21-204(b)          13828
# 22-226(a)          13438
# 55*                12366
# 22-406(i1)         11797
# 23-104             10760
#                    ...
# 24-106.2(d)            1
# 24-105(c22)            1
# 11-393.11(8)           1
# 21-1205.1(d)           1
# 11-392.10(a)           1
# 16-101(a2)             1
# ...

# %%
Traffic_Data[Traffic_Data['Charge'].astype(str).str.contains('21-801')].Description.value_counts()
# Out:
# EXCEEDING THE POSTED SPEED LIMIT OF 40 MPH                                                          21920
# EXCEEDING THE POSTED SPEED LIMIT OF 30 MPH                                                          21679
# EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH                                                          16110
# EXCEEDING MAXIMUM SPEED: 39 MPH IN A POSTED 30 MPH ZONE                                             12791
# FAILURE TO CONTROL VEHICLE SPEED ON HIGHWAY TO AVOID COLLISION                                      12598
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRUDENT SPEED ON HIGHWAY                                10815
# EXCEEDING THE POSTED SPEED LIMIT OF 55 MPH                                                           9648
# EXCEEDING THE POSTED SPEED LIMIT OF 45 MPH                                                           7834
# EXCEEDING MAXIMUM SPEED: 44 MPH IN A POSTED 35 MPH ZONE                                              7521
# ...

# %%
Speeding_data=Traffic_Data[Traffic_Data['Description'].astype(str).str.contains('SPEED')]

# %%
#Seeding Violation under 21-801.1', '21-801(b)', '21-801(a)', '21-1116(a)', '21-801(g)', '21-301(b)', '21-804(a)', '21-405(e2)', '21-802.1', '21-1125(1)',
#'21-801(h)', '21-801(e)', '21-804(b)', '77', '21-303(e)','21-804(c)', '21-1205(a)', '21-803.1(e)', '21-1409', '21-806(b)',
#'21-801(c)', '21-1125(3)', '21-805.1(a)', '21-801(d)',#'21-1205.1(a)', '21-1125(2)', '22-221(j)', '21-1125(4)', '21-801(f)', '21-604(e)', '21-1116(b)', '11-392.11'
Speeding_data.Description.value_counts()
#There are 32 charges under Speeding
Speeding_data.Charge.unique()
#There are 220741 types of Charges and Description
Speeding_data.count()
# Out:
# Description       220741
# Violation Type    220741
# Charge            220741
# Fatal             220741
# Race              220741
# Gender            220741
# Year              220741
# Month             220741
# dtype: int64

# %%
#Replacing all the Description under Speeding data as Speeding
Speeding_data.loc[Speeding_data['Description'].str.contains('SPEED', case=False), 'Description'] = 'SPEEDING'
# Out:
# C:\Users\lalit\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
#There are 55 counts of Fatality under speeding Speeding_data[Speeding_data.Fatal=='Yes'].count()
#138836M and 81877F

Speeding_data[Speeding_data.Gender=='F'].count()
Speeding_data.count()
# Out:
# Description       220741
# Violation Type    220741
# Charge            220741
# Fatal             220741
# Race              220741
# Gender            220741
# Year              220741
# Month             220741
# dtype: int64

# %%
#Replacing all the Charge under Speeding data as section 21-801
Speeding_data.loc[Speeding_data['Description'].str.contains('SPEED', case=False), 'Charge'] = '21-801'
# Out:
# C:\Users\lalit\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
Speeding_data.head()
# Out:
#    Description Violation Type  Charge Fatal      Race Gender  Year  Month
# 25    SPEEDING       Citation  21-801    No     OTHER      M  2013      3
# 41    SPEEDING       Citation  21-801    No     BLACK      M  2013      6
# 42    SPEEDING       Citation  21-801    No     WHITE      F  2013      5
# 48    SPEEDING       Citation  21-801    No  HISPANIC      F  2017      8
# 50    SPEEDING       Citation  21-801    No  HISPANIC      M  2013     10

# %%
Traffic_Data[Traffic_Data['Charge'].astype(str).str.contains('21-201')].Description.value_counts()
# Out:
# DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS                             110621
# DRIVE ACROSS PRIVATE PROPERTY FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE                         1936
# DRIVE ACROSS PRIVATE PROPERTY, LEAVE THE ROADWAY FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE       332
# LEAVE THE ROADWAY FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE                                       81
# DRIVE ACROSS PRIVATE PROPERTY, LEAVE THE ROADWAYFOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE         39
# DRIVE ACROSS PRIVATE PROPERTY, FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE                          23
# DRIVE ACROSS PRIVATE PROPERTY  FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE                          19
# DRIVE ACROSS PRIVATE PROPERTYFOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE                            15
# ...

# %%
Avoid_TCD_data=Traffic_Data[Traffic_Data['Description'].astype(str).str.contains('TRAFFIC CONTROL DEVICE')]

# %%
Avoid_TCD_data.Description.unique()
# Out:
# array(['DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS',
#        'DRIVE ACROSS PRIVATE PROPERTY FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE',
#        'DRIVING VEHICLE IN HOV LANE WHEN NOT AUTHORIZED BY TRAFFIC CONTROL DEVICE',
#        'DRIVE ACROSS PRIVATE PROPERTY, LEAVE THE ROADWAY FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE',
#        'DRIVER CHANGING LANES WHERE PROHIBITED BY TRAFFIC CONTROL DEVICE',
#        'LEAVE THE ROADWAY FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE',
#        'DRIVER FAILURE AT "T" INTERSECTION W/O TRAFFIC CONTROL DEVICE TO YIELD RIGHT-OF-WAY',
#        'DRIVE ACROSS PRIVATE PROPERTY,FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE',
#        'DRIVE ACROSS PRIVATE PROPERTY, FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE',
#        'DRIVE ACROSS PRIVATE PROPERTY  FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE',
#        'LEAVE THE ROADWAY )FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE',
# ...

# %%
#'21-201(a1)', '21-201(a2)', '21-314(b)', '21-309(e)', '21-401.1', '21-1003(o)' under avoid Traffic control Device
Avoid_TCD_data.Charge.unique()
#There are 6 Charges
Avoid_TCD_data.Charge.nunique()
# Out:
# 6

# %%
Avoid_TCD_data.loc[Avoid_TCD_data['Description'].str.contains('TRAFFIC CONTROL DEVICE', case=False), 'Description'] = ' AVOID TRAFFIC CONTROL DEVICE'
Avoid_TCD_data.loc[Avoid_TCD_data['Description'].str.contains('TRAFFIC CONTROL DEVICE', case=False), 'Charge'] = ' 21-201'
# Out:
# C:\Users\lalit\anaconda\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
Avoid_TCD_data
# Out:
#                            Description Violation Type   Charge Fatal  \
# 1         AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# 49        AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# 56        AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# 175       AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# 190       AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# 219       AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# 223       AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# 233       AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# 263       AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# 329       AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# 401       AVOID TRAFFIC CONTROL DEVICE        Warning   21-201    No
# 402       AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# 424       AVOID TRAFFIC CONTROL DEVICE       Citation   21-201    No
# ...

# %%
Traffic_Data[Traffic_Data['Charge'].astype(str).str.contains('13-409')].Description.value_counts()
# Out:
# FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER    65030
# FAILURE TO CARRY REGISTRATION CARD WITHIN VEHICLE                      1107
# FAIL TO DISPLAY REG. CARD ON DEMAND                                     375
# Name: Description, dtype: int64

# %%
#failure to show Registration card on demand 13-409(b)', '13-409(a)', '13-701(a)', '13-708(a)', '13-701(b)','13-708(b)', '13-415(c)', '14-108(a)', '14-107(j)', '13-415(a)',
#'13-703(f)', '13-415(b)', '13-703(b)', '11-392.2
REG_CARD_data=Traffic_Data[Traffic_Data['Description'].astype(str).str.contains('REGISTRATION CARD|REG. CARD')]

# %%
REG_CARD_data.Charge.unique()
#14 charges
REG_CARD_data.Charge.nunique()
Traffic_pd.count()
# Out:
# Date Of Stop               1373693
# Time Of Stop               1373693
# Agency                     1373693
# SubAgency                  1373683
# Description                1373684
# Location                   1373691
# Latitude                   1273524
# Longitude                  1273524
# Accident                   1373693
# Belts                      1373693
# Personal Injury            1373693
# Property Damage            1373693
# Fatal                      1373693
# Commercial License         1373693
# HAZMAT                     1373693
# Commercial Vehicle         1373693
# Alcohol                    1373693
# Work Zone                  1373693
# State                      1373634
# VehicleType                1373693
# Year Make                  1365292
# Make                       1373636
# Model                      1373503
# Color                      1357008
# Violation Type             1373693
# Charge                     1373693
# Article                    1305010
# ...

# %%
main_traffic_data=Traffic_pd.drop(columns={'Agency', 'SubAgency','Personal Injury', 'Property Damage','Work Zone','Article', 'Contributed To Accident'})

# %%
main_traffic_data.columns
final_data=main_traffic_data.drop(columns={'Location', 'Latitude','Longitude','Commercial License','Commercial Vehicle','Driver State','Arrest Type'})

# %%
final_data.shape
# Out:
# (1373693, 23)

# %%
final_data.Description.value_counts()
# Out:
# DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS                              110621
# FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER                                       65030
# DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION                                                   45589
# FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DISPLAY LICENSE TO UNIFORMED POLICE ON DEMAND                35893
# DRIVER USING HANDS TO USE HANDHELD TELEPHONE WHILEMOTOR VEHICLE IS IN MOTION                             33362
# DISPLAYING EXPIRED REGISTRATION PLATE ISSUED BY ANY STATE                                                32046
# DRIVER FAILURE TO STOP AT STOP SIGN LINE                                                                 30762
# PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUBLIC USE PROPERTY ON SUSPENDED LICENSE AND PRIVILEGE        27694
# ...

# %%
main_traffic_data.Description
# Out:
# 0          DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 1          DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC...
# 2                         FAILURE STOP AND YIELD AT THRU HWY
# 3                       FAILURE YIELD RIGHT OF WAY ON U TURN
# 4          FAILURE OF DR. TO MAKE LANE CHANGE TO AVAIL. L...
# 5          NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPR...
# 6          DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 7          DRIVER FAIL TO STOP AT FLASHING RED TRAFFIC SI...
# 8          FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DI...
# 9          DRIVING VEHICLE ON HIGHWAY WITH AN EXPIRED LIC...
# 10         FAILURE TO DRIVE ON RIGHT HAND ROADWAY OF DIVI...
# 11         DRIVER USING HANDS TO USE HANDHELD TELEPHONE W...
# 12              OCCUPANT UNDER 16 NOT RESTRAINED BY SEATBELT
# 13                         DRIVING WHILE IMPAIRED BY ALCOHOL
# 14                              FAILURE TO STOP AT STOP SIGN
# ...

# %%
final_data.dropna(how='any',inplace=True)
final_data.count()
# Out:
# Date Of Stop      1256658
# Time Of Stop      1256658
# Description       1256658
# Accident          1256658
# Belts             1256658
# Fatal             1256658
# HAZMAT            1256658
# Alcohol           1256658
# State             1256658
# VehicleType       1256658
# Year Make         1256658
# Make              1256658
# Model             1256658
# Color             1256658
# Violation Type    1256658
# Charge            1256658
# Race              1256658
# Gender            1256658
# Driver City       1256658
# DL State          1256658
# Geolocation       1256658
# Year              1256658
# Month             1256658
# dtype: int64

# %%
final_data[final_data['Charge'].astype(str).str.contains('21-707')].Description.value_counts()
final_data.loc[final_data['Description'].str.contains('DISPLAY LICENSE')].Charge.count()
final_data[final_data['Charge'].astype(str).str.contains('16-112')].Description.value_counts()
# Out:
# FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DISPLAY LICENSE TO UNIFORMED POLICE ON DEMAND    33192
# FAILURE OF INDIVIDUAL DRIVING ON HWY. TO HAVE LIC.WITH HIM                                     606
# VEH. DRIVER GIVING FALSE AND FICTITIOUS NAME TO UNIFORMED POLICE                               483
# FAIL TO DISPLAY LICENSE ON DEMAND                                                              185
# FAILURE OF INDIVIDUAL DRIVING ON HWY. TO SIGN SIGNATURE IF REQUESTED BY POLICE                   2
# Name: Description, dtype: int64

# %%
#final_data[final_data['Charge'].astype(str).str.contains('16-112')].Description.value_counts()
final_data.loc[final_data['Description'].str.contains('DISPLAY LICENSE|HAVE LIC.|FALSE AND FICTITIOUS NAME|SIGN SIGNATURE|LICENSE')].Charge.value_counts()
# Out:
# 16-112(c)        33377
# 16-101(a)        28431
# 16-303(c)        25621
# 16-303(h)        18951
# 16-116(a)        14721
# 16-303(d)         6491
# 16-101(a1)        4541
# 16-303(f)         3568
# 16-115(g)         2194
# 16-113(h)         2141
# 16-303(g)         1106
# 16-111.1(f)        682
# 16-115(f)          669
# 16-112(b)          606
# 16-112(e)          483
# 16-114(b)          477
# 16-101(b)          185
# 16-301(e)           62
# 11-393.9            50
# 16-114(d)           43
# 16-807(a)           30
# 15-111(a)           29
# 16-115(h)           26
# 16-201              19
# 12-301(j)           15
# 16-302              12
# 16-808(c)           11
# 16-116(b)           10
# 16-201(b)            8
# 15-302(a)            7
# 16-301(a)            6
# 13-113(c)            3
# 13-411(c1)           3
# 16-804               3
# 16-112(d)            2
# 13-113(e4)           2
# 16-807(e2)           2
# 13-113(b)            2
# 13-113(a)            2
# 16-116(c)            2
# ...

# %%
final_data.loc[final_data['Description'].str.contains('SPEED', case=False),'Description']='SPEED' 
final_data.loc[final_data['Description'].str.contains('SPEED', case=False),'Charge']='201-801'
final_data.loc[final_data['Description'].str.contains('TRAFFIC CONTROL DEVICE', case=False),'Description']='TRAFFIC CONTROL DEVICE' 
final_data.loc[final_data['Description'].str.contains('TRAFFIC CONTROL DEVICE', case=False),'Charge']='21-201'

# %%
final_data.loc[final_data['Description'].str.contains('REGISTRATION CARD|DISPLAY REG. CARD',case=False),'Description']='FAILURE TO DISPLAY REGISTRATION CARD'
final_data.loc[final_data['Description'].str.contains('REGISTRATION CARD|DISPLAY REG. CARD',case=False),'Charge']='13-409'

# %%
final_data.loc[final_data['Description'].str.contains('SUSPENDED REGISTRATION|UNREGISTERED MOTOR|UNPAID REGISTRATION|CANCELLED REGISTRATION|REVOKED REGISTRATION|UNREG. VEH| PROPER VEHICLE I.D', case=False),'Description']='SUSPENDED REGISTRATION' 
final_data.loc[final_data['Description'].str.contains('SUSPENDED REGISTRATION|UNREGISTERED MOTOR|UNPAID REGISTRATION|CANCELLED REGISTRATION|REVOKED REGISTRATION|UNREG. VEH| PROPER VEHICLE I.D', case=False),'Charge']='13-401'

# %%
final_data.loc[final_data['Description'].str.contains('STOP AT STOP|YIELD SIGN', case=False),'Description']='STOP AT STOP' 
final_data.loc[final_data['Description'].str.contains('STOP AT STOP|YIELD SIGN', case=False),'Charge']='21-707'

# %%
final_data.Description.value_counts()
# Out:
# SPEED                                                                                                   203611
# SUSPENDED LICENSE                                                                                       144611
# TRAFFIC CONTROL DEVICE                                                                                  107368
# ELECTRONIC DEVICE DISTRACTION                                                                            99895
# DISPLAY REGISTRATION PLATE                                                                               77664
# FAILURE TO DISPLAY REGISTRATION CARD                                                                     62134
# SUSPENDED REGISTRATION                                                                                   55386
# STOP AT STOP                                                                                             42237
# ...

# %%
final_data.Charge.value_counts()
# Out:
# 201-801          203611
# 16-112           144611
# 21-201           107368
# 21-1124           99895
# 13-411            77664
# 13-409            62134
# 13-401            55386
# 21-707            42237
# 21-309            34567
# 22-412            31264
# 64                24901
# 22-201.1          17624
# 21-901.1(b)       16037
# 21-202(h1)        15046
# 21-204(b)         12761
# 22-226(a)         12469
# 21-902(b1)        11639
# 21-902(a1)        11430
# 22-406(i1)        11362
# 55*               11046
# 23-104            10253
# 21-301(a)          9608
# 21-204(d)          9262
# 16-303(h)          7733
# 21-902(a2)         7709
# 17-107             7656
# 21-402(a)          7534
# 61                 7348
# 16-301(j)          6736
# 22-206(a)          6244
#                   ...
# 21-904(e2)            1
# 21-10A04A(5)          1
# 22-228(d)             1
# 21-1205.1(b2)         1
# 10-319.2              1
# 21-1206(a)            1
# 22-412.2(e)           1
# ...

# %%
final_data.loc[final_data['Description'].str.contains('DISPLAY LICENSE|HAVE LIC.|FALSE AND FICTITIOUS NAME|SIGN SIGNATURE|LICENSE'),'Description']='SUSPENDED LICENSE'
final_data.loc[final_data['Description'].str.contains('DISPLAY LICENSE|HAVE LIC.|FALSE AND FICTITIOUS NAME|SIGN SIGNATURE|LICENSE'),'Charge']='16-112'
# Out:
# C:\Users\lalit\anaconda\Anaconda3\envs\PythonData\lib\site-packages\ipykernel\__main__.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   if __name__ == '__main__':

# %%
final_data[final_data['Charge'].astype(str).str.contains('22-412')].Description.unique()
# Out:
# array(['OCCUPANT UNDER 16 NOT RESTRAINED BY SEATBELT',
#        'OPERATOR NOT RESTRAINED BY SEATBELT',
#        'PASSENGER AGE 16 OR MORE IN OUTBOARD FRONT SEAT OF MOTOR VEHICLE WITHOUT SEATBELT RESTRAINT',
#        'OPER. MOTOR VEH. WITH OPERATOR NOT RESTRAINED BY SEAT BELT',
#        'FAILING TO SECURE CHILD UNDER AGE 8 IN CHILD SAFETY SEAT WHEN TRANSPORTING IN MOTOR VEHICLE',
#        'PERSON WITH MD REG. VEHICLE FAILING TO TRANSPORT CHILD WEIGHING 40 LBS OR LESS IN CHILD SAFETY SEAT',
#        'OPER. M/V WITH OPERATOR NOT RESTRAINED BY SEATBELT',
#        'FAIL TO TRANSPORT CHILD UNDER AGE 16 IN A SEAT BELT',
#        'PASSENGER AGE 16 OR MORE IN OUTBOARD FRONT SEAT OF MOTOR VEHICLE W/O SEAT BELT RESTRAINT',
#        'FAIL TO TRANSPORT CHILD UNDER AGE 16 IN  A SEAT BELT',
#        'OPER. MOTOR VEH. WITH OCCUPANT UNDER 16 NOT RESTRAINED BY SEAT BELT',
#        'USING A SEAT BELT TO SEAT MORE THAN ONE INDIVIDUAL',
# ...

# %%
final_data.loc[final_data['Description'].str.contains('ELECTRONIC|TEXT|TELEPHONE|ATEXT|WIRELESS COMMUNICATION|WRITING|SENDING|MSG.|PHONE|EAR'),'Description']="ELECTRONIC DEVICE DISTRACTION"
final_data.loc[final_data['Description'].str.contains('ELECTRONIC|TEXT|TELEPHONE|ATEXT|WIRELESS COMMUNICATION|WRITING|SENDING|MSG.|PHONE|EAR'),'Charge']="21-1124"

# %%
final_data.loc[final_data['Description'].str.contains('REGISTRATION PLATE|VALIDATION TABS|PLATE|TAGS|REG. PLATE'),"Description"]="DISPLAY REGISTRATION PLATE"
final_data.loc[final_data['Description'].str.contains('REGISTRATION PLATE|VALIDATION TABS|PLATE|TAGS|REG. PLATE'),"Charge"]="13-411"

# %%
final_data.loc[final_data['Description'].astype(str).str.contains('STOP LIGHTS',case=False),"Description"]="NO STOP LIGHTS"
final_data.loc[final_data['Description'].astype(str).str.contains('STOP LIGHTS',case=False),"Charge"]="64"

# %%
final_data.loc[final_data['Description'].astype(str).str.contains('seat|seatbelt|belt',case=False),"Description"]="NO SEAT BELT/CHILD SAFTEY"
final_data.loc[final_data['Description'].astype(str).str.contains('seat|seatbelt|belt',case=False),"Charge"]="22-412"

# %%
final_data[final_data['Charge'].astype(str).str.contains('21-309',case=False)].Description.value_counts()
final_data[final_data['Description'].astype(str).str.contains('lane',case=False)].Charge.unique()
# Out:
# MOTORCYCLE OPERATOR OVERTAKING AND PASSING VEH. IN SAME LANE                               59
# OPERATING MOTORCYCLE BETWEEN LANES OF TRAFFIC                                              21
# OPERATING MOTORCYCLE BETWEEN LANES OF TRAFFIC, ADJACENT LINES OF VEHS., ROWS OF VEHS.      15
# OPERATING MOTORCYCLE BETWEEN LANES OF TRAFFIC.                                              5
# OPERATING MOTORCYCLE BETWEEN ROWS OF VEHS.                                                  4
# OPERATING MOTORCYCLE BETWEEN ROWS OF VEHS                                                   2
# OPERATING MOTORCYCLE BETWEEN  ROWS OF VEHS.                                                 1
# OPERATING MOTORCYCLE BETWEEN ADJACENT LINES OF VEHS                                         1
# OPERATING MOTORCYCLE BETWEEN LANES OF TRAFFIC,  ADJACENT LINES OF VEHS.,  ROWS OF VEHS.     1
# OPERATING MOTORCYCLE BETWEEN LANES OF TRAFFIC AND ROWS OF VEHS                              1
# ...

# %%
final_data.loc[final_data['Description'].astype(str).str.contains('lane',case=False),"Description"]="IMPROPER LANE CHANGE"
final_data.loc[final_data['Description'].astype(str).str.contains('lane',case=False),"Charge"]="21-309"
